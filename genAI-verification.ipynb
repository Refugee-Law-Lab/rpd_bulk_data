# %% [markdown]
# ### Notebook to verify data parsing using GPT4

# %%
# Importing Libraries
from langchain.schema.messages import HumanMessage, SystemMessage
from langchain.chat_models import ChatOpenAI
import pandas as pd
import json
import pathlib

# %% [markdown]
# ### Setup LLM Models

# %%
# Get API Key
with open('d:/AI-Projects/secrets/SECRETS-OPENAI.txt', 'r') as in_file:
    OPENAI_API_KEY = in_file.readlines()[0]

# Set up LLM
gpt = ChatOpenAI(model="gpt-4-1106-preview", openai_api_key=OPENAI_API_KEY, temperature=0, max_tokens=1024)

def get_response(prompt, system_message):
    messages = [
    SystemMessage(content=system_message),
    HumanMessage(content=prompt),
    ]
    return gpt.invoke(messages).content

# %%
def get_decision_date (case_excerpt):
    system_message = """You are a helpful research assistant for a Canadian law professor.
    You are given a case exerpt and you return only the date of the decision in YYYY-MM-DD format. 
    If you are not sure about the date, you return 'other'. 
    """
    prompt = f"CASE EXCERPT: {case_excerpt} /n/n/n DATE OF DECISION in YYYY-MM-DD format (other if unclear): "

    return get_response(prompt, system_message)

def get_rad_decision (case_excerpt):
    system_message = """You are a helpful research assistant for a Canadian law professor.
    You are given a case exerpt and you return only 'RPD' if the case excerpt is a decision
    of the Refugee Protection Division of the Immigration and Refugee Board, 'other' if it is 
    a different IRB division (e.g. Immigration Division, Immigration Appeal Division, Refugee 
    Appeal Division, Refugee Division) or if you are not sure. Keep in mind that 'Refugee Protection Division'
    and 'Refugee Division' are not the same.
    """
    prompt = f"CASE EXCERPT: {case_excerpt} /n/n/n RPD or other: "

    return get_response(prompt, system_message)

# %% [markdown]
# ### Load the data

# %%
# get parsed data

# Set variables
start_year = 2001  # First year of data sought (2003 +)
end_year = 2020  # Last year of data sought (2021 -)
languages_sought = ['en', 'fr']  # languages in list e.g. ['en', 'fr'] or ['en']

# Set path to data
data_path = pathlib.Path('DATA/YEARLY/')

# load data
results = []
for year in range(start_year, end_year+1):
    for language in languages_sought:
        with open(data_path / f'{year}_{language}.json') as f:
            results.extend(json.load(f))

# convert to dataframe
df = pd.DataFrame(results)

df
# Out:
#         citation citation2 dataset name   source_url scraped_timestamp
# 0      MA1-12669               RPD        486359.txt        2023-11-13  \
# 1      AA0-01604               RPD        638019.txt        2023-11-13
# 2      AA1-00073               RPD        638027.txt        2023-11-13
# 3      AA1-00454               RPD        638041.txt        2023-11-13
# 4      AA1-01289               RPD        638047.txt        2023-11-13
# ...          ...       ...     ...  ...          ...               ...
# 12463  VB9-04335               RPD       3568407.txt        2023-11-13
# 12464  TB0-04269               RPD       3580919.txt        2023-11-13
# 12465  TB8-03337               RPD       3580931.txt        2023-11-13
# 12466  MB9-01194               RPD       3581415.txt        2023-11-13
# 12467  TB3-09544               RPD       3594187.txt        2023-11-13
#
#       document_date  year                                    unofficial_text
# 0        2002-08-22  2002  Immigration and Refugee Board\nRefugee Protect...  \
# 1        2002-11-08  2002  Immigration and Refugee Board\nRefugee Protect...
# 2        2002-11-06  2002  Immigration and Refugee Board\nRefugee Protect...
# 3        2002-11-01  2002  Immigration and Refugee Board\nRefugee Protect...
# 4        2002-10-17  2002  Immigration and Refugee Board\nRefugee Protect...
# ...             ...   ...                                                ...
# 12463    2020-01-28  2020  \nDossier de la SPR / RPD File: VB9-04335/0434...
# 12464    2020-02-04  2020  \nNo de dossier de la SPR / RPD File No.: TB0-...
# 12465    2020-02-24  2020  \nNo de dossier de la SPR / RPD File No.: TB8-...
# 12466    2020-07-27  2020  Dossier de la SPR / RPD File: MB9-01194\nHuis ...
# 12467    2020-02-04  2020  \nNo de dossier de la SPR / SPR File No.: TB3-...
#
#       language                                      other
# 0           en              {"decision-maker_name": null}
# 1           en              {"decision-maker_name": null}
# 2           en              {"decision-maker_name": null}
# 3           en              {"decision-maker_name": null}
# 4           en              {"decision-maker_name": null}
# ...        ...                                        ...
# 12463       fr  {"decision-maker_name": "Megan Kammerer"}
# 12464       fr         {"decision-maker_name": "H. ROSS"}
# 12465       fr     {"decision-maker_name": "A. Casimiro"}
# 12466       fr    {"decision-maker_name": "Michel Colin"}
# 12467       fr       {"decision-maker_name": "K. Khamsi"}
#
# [12468 rows x 11 columns]

# %%
# get raw data
DATA_DIRS = ["d:/IRB Decisions - Initial Request - TEXT/"]

# get list of files in each directory, including full path
path_file_list = []
for data_dir in DATA_DIRS:
    for file in pathlib.Path(data_dir).glob('**/*'):
        path_file_list.append(str(file))

# put the file_list into a dataframe
df_raw = pd.DataFrame(path_file_list, columns=['path_file_name'])

# add a column with just the file name (using pathlib
df_raw['file_name'] = df_raw['path_file_name'].apply(lambda x: pathlib.Path(x).name)

df_raw
# Out:
#                                            path_file_name     file_name
# 0       d:\IRB Decisions - Initial Request - TEXT\1000...   1000064.txt
# 1       d:\IRB Decisions - Initial Request - TEXT\1000...   1000599.txt
# 2       d:\IRB Decisions - Initial Request - TEXT\1000...   1000602.txt
# 3       d:\IRB Decisions - Initial Request - TEXT\1000...   1000606.txt
# 4       d:\IRB Decisions - Initial Request - TEXT\1000...   1000607.txt
# ...                                                   ...           ...
# 116683  d:\IRB Decisions - Initial Request - TEXT\9996...    999668.txt
# 116684  d:\IRB Decisions - Initial Request - TEXT\9996...    999669.txt
# 116685  d:\IRB Decisions - Initial Request - TEXT\9996...    999670.txt
# 116686  d:\IRB Decisions - Initial Request - TEXT\~$03...  ~$036980.txt
# 116687  d:\IRB Decisions - Initial Request - TEXT\~$52...  ~$526686.txt
#
# [116688 rows x 2 columns]

# %% [markdown]
# ### Select a random sample of the data

# %%
# set random seed
import random
random.seed(2023)

# get random sample of df
df_sample = df.sample(n=500)

# get random sample of df_raw
df_sample_raw = df_raw.sample(n=500)

# open the text files in df_sample_raw, using file_name colum (and pathlib), and save content to unofficial_text column, being sure to close the file, with unicode encoding
df_sample_raw['unofficial_text'] = df_sample_raw['path_file_name'].apply(lambda x: pathlib.Path(x).open(encoding='utf-8', errors='ignore').read())
df_sample_raw
# Out:
#                                            path_file_name    file_name
# 63994   d:\IRB Decisions - Initial Request - TEXT\2896...  2896929.txt  \
# 40588   d:\IRB Decisions - Initial Request - TEXT\1886...  1886080.txt
# 41902   d:\IRB Decisions - Initial Request - TEXT\1901...  1901809.txt
# 42642   d:\IRB Decisions - Initial Request - TEXT\1918...  1918882.txt
# 27601   d:\IRB Decisions - Initial Request - TEXT\1754...  1754112.txt
# ...                                                   ...          ...
# 113764  d:\IRB Decisions - Initial Request - TEXT\9406...   940613.txt
# 373     d:\IRB Decisions - Initial Request - TEXT\1009...  1009107.txt
# 18460   d:\IRB Decisions - Initial Request - TEXT\1237...  1237426.txt
# 77075   d:\IRB Decisions - Initial Request - TEXT\3207...  3207812.txt
# 79202   d:\IRB Decisions - Initial Request - TEXT\3301...  3301249.txt
#
#                                           unofficial_text
# 63994   Commission de l'immigration et\ndu statut de r...
# 40588   \nImmigration and\nRefugee Board of Canada\n\n...
# 41902   \nImmigration and\nRefugee Board of Canada\n\n...
# 42642   Commission de l'immigration\net du statut de r...
# 27601   \n\nMotifs et dcision - Reasons and Decision\n...
# ...                                                   ...
# 113764  Immigration and\nRefugee Board\nImmigration Ap...
# 373     \n\nIAD File No. / No de dossier de la SAI: TA...
# 18460   \n\nRPD File No. / N de dossier de la SPR : TB...
# 77075    \tRPD File No. / N de dossier de la SPR : TB7...
# 79202   \nCommission de l'immigration et du statut de ...
#
# [500 rows x 3 columns]

# %% [markdown]
# ### Apply the models to the data

# %%
# iterate through the sample, pick first 1000 characters of unofficial_text and get response, using df.apply
df_sample['genAI_decision_date'] = df_sample['unofficial_text'].apply(lambda x: get_decision_date(x[:1000]))
df_sample
# Out:
#         citation citation2 dataset name   source_url scraped_timestamp
# 12447  TB9-28520               RPD       3329366.txt        2023-11-13  \
# 10693  MB1-01279               RPD       1820804.txt        2023-11-12
# 8415   TA9-23060               RPD       1393204.txt        2023-11-12
# 10277  MB1-00905               RPD       1830138.txt        2023-11-12
# 5251   MA8-06880               RPD       1126114.txt        2023-11-12
# ...          ...       ...     ...  ...          ...               ...
# 3341   MA6-04696               RPD        774135.txt        2023-11-13
# 2785   MA6-08613               RPD       1013235.txt        2023-11-12
# 1512   CA5-00488               RPD       1096783.txt        2023-11-12
# 8227   TB0-06040               RPD       1301568.txt        2023-11-12
# 11727  TB6-16896               RPD       2730846.txt        2023-11-13
#
#       document_date  year                                    unofficial_text
# 12447    2020-01-02  2020  RPD File /Dossier de la SPR :\nTB9-28520\nUCI ...  \
# 10693    2014-06-02  2014  Immigration and Refugee Board\nRefugee Protect...
# 8415     2012-06-05  2012  \nN° de dossier de la SPR / RPD File No.: TA9-...
# 10277    2014-07-24  2014  Immigration and\nRefugee Board\nRefugee Protec...
# 5251     2010-08-09  2010  Commission de l'immigration\net du statut de r...
# ...             ...   ...                                                ...
# 3341     2008-03-27  2008  Commission de l'immigration et du statut de ré...
# 2785     2008-10-07  2008  Immigration and\nRefugee Board\nRefugee Protec...
# 1512     2006-08-04  2006  Commission de l'immigration et du statut de ré...
# 8227     2012-06-18  2012  \nNo de dossier de la SPR / RPD File No.: TB0-...
# 11727    2017-03-15  2017  RPD File No. / N° de dossier de la SPR : TB6-1...
#
#       language                                        other
# 12447       en           {"decision-maker_name": "L. Figg"}  \
# 10693       fr                {"decision-maker_name": null}
# 8415        fr  {"decision-maker_name": "Pasquale Fiorino"}
# 10277       en                {"decision-maker_name": null}
# 5251        fr                  {"decision-maker_name": ""}
# ...        ...                                          ...
# 3341        fr                {"decision-maker_name": null}
# 2785        en                {"decision-maker_name": null}
# 1512        fr                {"decision-maker_name": null}
# 8227        fr      {"decision-maker_name": "Walter Kawun"}
# 11727       en           {"decision-maker_name": "L. Figg"}
#
#       genAI_decision_date
# 12447          2020-01-02
# 10693          2014-06-02
# 8415           2012-06-05
# 10277          2014-07-24
# 5251           2010-08-09
# ...                   ...
# 3341           2008-03-27
# 2785           2008-10-07
# 1512           2006-08-04
# 8227           2012-07-23
# 11727          2017-03-15
#
# [500 rows x 12 columns]

# %%
# list any rows of the df where genAI_decision_date is not equal to the decision_date
df_sample[df_sample['genAI_decision_date'] != df_sample['document_date']]
# Out:
#        citation citation2 dataset name   source_url scraped_timestamp
# 3801  TA6-03866               RPD       1119046.txt        2023-11-12  \
# 9003  VB2-01681               RPD       1559871.txt        2023-11-12
# 5679  VA9-00853               RPD       1299095.txt        2023-11-12
# 5363  VA9-02032               RPD       1149053.txt        2023-11-12
# 9153  TB0-15885               RPD       1740390.txt        2023-11-12
# 8389  TB1-06383               RPD       1391410.txt        2023-11-12
# 4709  VA9-02032               RPD       1148996.txt        2023-11-12
# 8227  TB0-06040               RPD       1301568.txt        2023-11-12
#
#      document_date  year                                    unofficial_text
# 3801    2009-04-08  2009  \nRPD File No. / N° de dossier de la SPR : TA6...  \
# 9003    2013-05-22  2013  \nRPD File No. / No de dossier de SPR : VB2-01...
# 5679    2010-12-13  2010  \nNo de dossier de la SPR / RPD File No.: VA9-...
# 5363    2010-11-24  2010  \nNo de dossier de la SPR / RPD File No.: VA9-...
# 9153    2013-07-03  2013  \nRPD File No. / N° de dossier de la SPR : TB0...
# 8389    2012-05-17  2012  \nNo de dossier de la SPR / RPD File No.: TB1-...
# 4709    2010-11-24  2010  \nRPD File No. / No de dossier de SPR : VA9-02...
# 8227    2012-06-18  2012  \nNo de dossier de la SPR / RPD File No.: TB0-...
#
#      language                                         other
# 3801       en  {"decision-maker_name": "Robert H. Rushowy"}  \
# 9003       en                 {"decision-maker_name": null}
# 5679       fr                 {"decision-maker_name": null}
# 5363       fr                 {"decision-maker_name": null}
# 9153       en  {"decision-maker_name": "Luis F. Agostinho"}
# 8389       fr    {"decision-maker_name": "Barry D. Barnes"}
# 4709       en                 {"decision-maker_name": null}
# 8227       fr       {"decision-maker_name": "Walter Kawun"}
#
#      genAI_decision_date
# 3801          2009-06-11
# 9003          2013-06-06
# 5679          2011-01-19
# 5363          2010-12-13
# 9153          2013-07-31
# 8389          2012-07-27
# 4709          2010-12-13
# 8227          2012-07-23

# %%
# iterate through the sample, pick first 1000 characters of unofficial_text and get response, using df.apply
df_sample['genAI_dataset'] = df_sample['unofficial_text'].apply(lambda x: get_rad_decision(x[:1000]))
df_sample
# Out:
#         citation citation2 dataset name   source_url scraped_timestamp
# 12447  TB9-28520               RPD       3329366.txt        2023-11-13  \
# 10693  MB1-01279               RPD       1820804.txt        2023-11-12
# 8415   TA9-23060               RPD       1393204.txt        2023-11-12
# 10277  MB1-00905               RPD       1830138.txt        2023-11-12
# 5251   MA8-06880               RPD       1126114.txt        2023-11-12
# ...          ...       ...     ...  ...          ...               ...
# 3341   MA6-04696               RPD        774135.txt        2023-11-13
# 2785   MA6-08613               RPD       1013235.txt        2023-11-12
# 1512   CA5-00488               RPD       1096783.txt        2023-11-12
# 8227   TB0-06040               RPD       1301568.txt        2023-11-12
# 11727  TB6-16896               RPD       2730846.txt        2023-11-13
#
#       document_date  year                                    unofficial_text
# 12447    2020-01-02  2020  RPD File /Dossier de la SPR :\nTB9-28520\nUCI ...  \
# 10693    2014-06-02  2014  Immigration and Refugee Board\nRefugee Protect...
# 8415     2012-06-05  2012  \nN° de dossier de la SPR / RPD File No.: TA9-...
# 10277    2014-07-24  2014  Immigration and\nRefugee Board\nRefugee Protec...
# 5251     2010-08-09  2010  Commission de l'immigration\net du statut de r...
# ...             ...   ...                                                ...
# 3341     2008-03-27  2008  Commission de l'immigration et du statut de ré...
# 2785     2008-10-07  2008  Immigration and\nRefugee Board\nRefugee Protec...
# 1512     2006-08-04  2006  Commission de l'immigration et du statut de ré...
# 8227     2012-06-18  2012  \nNo de dossier de la SPR / RPD File No.: TB0-...
# 11727    2017-03-15  2017  RPD File No. / N° de dossier de la SPR : TB6-1...
#
#       language                                        other
# 12447       en           {"decision-maker_name": "L. Figg"}  \
# 10693       fr                {"decision-maker_name": null}
# 8415        fr  {"decision-maker_name": "Pasquale Fiorino"}
# 10277       en                {"decision-maker_name": null}
# 5251        fr                  {"decision-maker_name": ""}
# ...        ...                                          ...
# 3341        fr                {"decision-maker_name": null}
# 2785        en                {"decision-maker_name": null}
# 1512        fr                {"decision-maker_name": null}
# 8227        fr      {"decision-maker_name": "Walter Kawun"}
# 11727       en           {"decision-maker_name": "L. Figg"}
#
#       genAI_decision_date genAI_dataset
# 12447          2020-01-02           RPD
# 10693          2014-06-02           RPD
# 8415           2012-06-05           RPD
# 10277          2014-07-24           RPD
# 5251           2010-08-09           RPD
# ...                   ...           ...
# 3341           2008-03-27           RPD
# 2785           2008-10-07           RPD
# 1512           2006-08-04           RPD
# 8227           2012-07-23           RPD
# 11727          2017-03-15           RPD
#
# [500 rows x 13 columns]

# %%
# list any rows of the df where genAI_dataset is not equal to the dataset
df_sample[df_sample['genAI_dataset'] != df_sample['dataset']]
# Out:
#         citation citation2 dataset name   source_url scraped_timestamp
# 2166   TA5-11822               RPD        636351.txt        2023-11-13  \
# 11083  MB4-05069               RPD       1849494.txt        2023-11-12
#
#       document_date  year                                    unofficial_text
# 2166     2007-12-17  2007  \nReasons and Decision ? Motifs et décision\nJ...  \
# 11083    2015-06-18  2015  Immigration and\nRefugee Board of Canada\nRefu...
#
#       language                                           other
# 2166        en         {"decision-maker_name": "Lois D. Figg"}  \
# 11083       en  {"decision-maker_name": "Me Maria De Andrade"}
#
#       genAI_decision_date genAI_dataset
# 2166           2007-12-17         other
# 11083          2015-06-18         other

# %%
# iterate through the sample, pick first 1000 characters of unofficial_text and get response, using df.apply
df_sample_raw['genAI_dataset'] = df_sample_raw['unofficial_text'].apply(lambda x: get_rad_decision(x[:1000]))
df_sample_raw
# Out:
#                                            path_file_name    file_name
# 63994   d:\IRB Decisions - Initial Request - TEXT\2896...  2896929.txt  \
# 40588   d:\IRB Decisions - Initial Request - TEXT\1886...  1886080.txt
# 41902   d:\IRB Decisions - Initial Request - TEXT\1901...  1901809.txt
# 42642   d:\IRB Decisions - Initial Request - TEXT\1918...  1918882.txt
# 27601   d:\IRB Decisions - Initial Request - TEXT\1754...  1754112.txt
# ...                                                   ...          ...
# 113764  d:\IRB Decisions - Initial Request - TEXT\9406...   940613.txt
# 373     d:\IRB Decisions - Initial Request - TEXT\1009...  1009107.txt
# 18460   d:\IRB Decisions - Initial Request - TEXT\1237...  1237426.txt
# 77075   d:\IRB Decisions - Initial Request - TEXT\3207...  3207812.txt
# 79202   d:\IRB Decisions - Initial Request - TEXT\3301...  3301249.txt
#
#                                           unofficial_text genAI_dataset
# 63994   Commission de l'immigration et\ndu statut de r...         other
# 40588   \nImmigration and\nRefugee Board of Canada\n\n...         other
# 41902   \nImmigration and\nRefugee Board of Canada\n\n...         other
# 42642   Commission de l'immigration\net du statut de r...         other
# 27601   \n\nMotifs et dcision - Reasons and Decision\n...         other
# ...                                                   ...           ...
# 113764  Immigration and\nRefugee Board\nImmigration Ap...         other
# 373     \n\nIAD File No. / No de dossier de la SAI: TA...         other
# 18460   \n\nRPD File No. / N de dossier de la SPR : TB...           RPD
# 77075    \tRPD File No. / N de dossier de la SPR : TB7...           RPD
# 79202   \nCommission de l'immigration et du statut de ...         other
#
# [500 rows x 4 columns]

# %%
# list any rows of df_sample_raw where genAI_dataset is 'RPD' but the file_name is not in df.source_url
df_sample_raw[(df_sample_raw['genAI_dataset'] == 'RPD') & (~df_sample_raw['file_name'].isin(df['source_url']))]
# Out:
#                                           path_file_name    file_name
# 88432  d:\IRB Decisions - Initial Request - TEXT\3596...  3596229.txt  \
# 78475  d:\IRB Decisions - Initial Request - TEXT\3263...  3263509.txt
# 46146  d:\IRB Decisions - Initial Request - TEXT\2040...  2040865.txt
# 57223  d:\IRB Decisions - Initial Request - TEXT\2731...  2731087.txt
# 30909  d:\IRB Decisions - Initial Request - TEXT\1783...  1783566.txt
# 15241  d:\IRB Decisions - Initial Request - TEXT\1175...  1175564.txt
# 87857  d:\IRB Decisions - Initial Request - TEXT\3590...  3590920.txt
# 41578  d:\IRB Decisions - Initial Request - TEXT\1899...  1899035.txt
# 71050  d:\IRB Decisions - Initial Request - TEXT\3064...  3064606.txt
# 41380  d:\IRB Decisions - Initial Request - TEXT\1895...  1895130.txt
#
#                                          unofficial_text genAI_dataset
# 88432  \nDossier de la SPR / RPD File: TC0-11107\nIUC...           RPD
# 78475  \nRAD File / Dossier de la SAR : TB9-09177\nTB...           RPD
# 46146  RPD File No. / N de dossier de la SPR : MB5-02...           RPD
# 57223  Commission de l'immigration\net du statut de r...           RPD
# 30909  \n\n\nNo de dossier de la SPR / RPD File No.: ...           RPD
# 15241  \n\nN de dossier de la SPR / RPD File No.: TA9...           RPD
# 87857  RPD File / Dossier de la SPR : TB2-10060\nTB2-...           RPD
# 41578  RPD File No. / N de dossier de la SPR : MB4-04...           RPD
# 71050  \nDossier de la SAR / RAD File : MB8-12204\n\n...           RPD
# 41380  \nNo de dossier de la SI / ID File No.: 0018-B...           RPD

# %%
# list any rows of df_sample_raw where genAI_dataset is 'other' and the file_name is in df.source_url
df_sample_raw[(df_sample_raw['genAI_dataset'] != 'RPD') & (df_sample_raw['file_name'].isin(df['source_url']))]
# Out:
# Empty DataFrame
# Columns: [path_file_name, file_name, unofficial_text, genAI_dataset]
# Index: []

# %%
# loop through these df_sample_raw[(df_sample_raw['genAI_dataset'] == 'RPD') & (~df_sample_raw['file_name'].isin(df['source_url']))]

cases_to_examine = df_sample_raw[(df_sample_raw['genAI_dataset'] == 'RPD') & (~df_sample_raw['file_name'].isin(df['source_url']))]

# iterate through cases_to_examine, print the filename, open the file, print the content

for index, row in cases_to_examine.iterrows():
    print(row['file_name'])

    with open(row['path_file_name'], encoding='utf-8', errors='ignore') as f:
        print(f.read())

    print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
# Out:
# 3596229.txt
#
# Dossier de la SPR / RPD File: TC0-11107
# IUC / UCI: XXXX
# Huis clos / Private Proceeding
# Motifs et dcision ? Reasons and Decision
# Demandeur(e)(s) d'asile
# XXXX XXXX XXXX
# Claimant(s)
#
#
#
# Date(s) de l'audience
# 18 juin 2021
#
# Date(s) of hearing
#
#
#
# Lieu de l'audience
# Tenue virtuellement
# Place of hearing
#
#
#
# Date de la dcision
# et des motifs
# 29 juin 2021
#
# Date of decision
# and reasons
#
#
#
# Tribunal
# Yonatan Rozenszajn
#
# Panel
#
#
#
# Conseil(s) du (de la/des)
# demandeur(e)(s) d'asile
# John Rokakis
# Counsel for the claimant(s)
#
#
#
# Reprsentant(e) dsign(e)
# S.O.
# Designated representative
#
#
#
# Conseil du (de la) ministre
# Numa Qadri
# Counsel for the Minister
#
# INTRODUCTION
# [1] Voici la dcision concernant la demande1 prsente par le ministre de la Citoyennet et de l'Immigration (le ministre) au titre de l'article 108 de la Loi sur l'immigration et la protection des rfugis (LIPR). Le ministre prsente une demande de constat de perte de l'asile accord par la Section de la protection des rfugis (SPR)  l'intim, XXXX XXXX XXXX.
# [2] L'intim a assist  l'audience en prsence d'un conseil et a produit un certain nombre de documents dans le cadre de sa rponse2. Le conseil a prsent des observations de vive voix concernant le bien-fond de la demande du ministre. Il a galement prsent une demande distincte pour qu'il soit sursis  la demande du ministre en raison d'un abus de procdure.
# LE SURSIS NE DEVRAIT PAS TRE ACCORD
# [3] L'intim a demand un sursis de la procdure relative  la perte de l'asile pour cause de retard. L'intim s'appuie sur le fait qu'un agent de l'Agence des services frontaliers du Canada (ASFC) responsable de l'entrevue lui a dit le XXXX XXXX 2014 que son dossier serait dfr  l'ASFC aux fins d'enqute et de constat de perte de l'asile3. L'intim conteste le fait que le ministre a prsent la demande de constat de perte de l'asile seulement le 19 octobre 2020, soit six (6) ans aprs que le dossier a t " dfr ", alors que l'intim a toujours t honnte avec les autorits canadiennes concernant ses voyages en Iraq. Il affirme tre victime de prjudice parce que ses souvenirs se sont effacs au fil des ans, particulirement en ce qui a trait  ses premiers voyages en 2008. L'intim s'appuie sur la dcision de la Cour fdrale dans l'arrt Godinez Ovalle c. Canada (MCI)4, dans lequel le juge Russell a accord une ordonnance de mandamus annulant la suspension du traitement de la demande de citoyennet du demandeur dans l'attente du rsultat de la procdure de perte de statut. L'intim devant moi a lui aussi vcu une longue suspension du traitement de sa demande de citoyennet.
# [4] Dans l'affaire Godinez Ovalle, le juge Russell a fond son jugement sur son interprtation troite de l'article 13.1 de la Loi sur la citoyennet, selon laquelle le traitement d'une demande de citoyennet n'a pas  tre suspendu en raison de proccupations quant  une perte de statut. Pour le juge Russell, les enqutes au titre de l'article 13.1 doivent porter sur des questions de scurit et d'admissibilit. L'intim se fonde sur ces observations, notamment une dclaration de la Cour selon laquelle il serait inhumain de s'appuyer sur l'article 13.1 pour arrter le traitement de demandes de citoyennet alors que le ministre connaissait le risque de perte de l'asile tout au long de renouvellements rpts de la rsidence permanente5.
# [5]  mon avis, la demande de sursis doit tre rejete parce qu'il se pourrait que l'affaire Godinez Ovalle ne soit pas fonde en droit et que, dans tous les cas, elle ne s'applique pas aux circonstances de la prsente affaire. En 2018, une autre juge de la Cour fdrale, la juge Sylvie E. Roussel, a tabli dans l'affaire GPP c. Canada (MCI)6 que l'affaire Godinez Ovalle s'applique (s'il y a lieu) seulement quand la demande de citoyennet a t prsente avant l'entre en vigueur de l'article 13.1 de la Loi sur la citoyennet7. La juge Roussell ajoutait que l'article 13.1 de la Loi sur la citoyennet est entr en vigueur le 1er aot 20148, et elle a rejet la demande de mandamus visant le traitement de la demande de citoyennet suspendue, la suspension dcoulant l aussi de proccupations concernant la perte de l'asile. Une question a t certifie  l'intention de la Cour d'appel fdrale. Le 4 avril 2019, la Cour d'appel fdrale a rpondu par l'affirmative  la question suivante et, par la mme occasion, elle a confirm le jugement de la juge Roussell :
# Est-ce que l'article 13.1 de la Loi sur la citoyennet, LRC 1985, ch. C-29, permet au ministre de suspendre une demande de citoyennet prsente avant le 1er aot 2014 et dont il n'a pas t dcid dfinitivement avant cette date?
# Rponse : oui9.
# [6] Aprs que la Cour d'appel fdrale eut rendu sa dcision, un autre juge de la Cour fdrale, le juge Richard Mosely, a statu que, dans la dcision Godinez Ovalle, l'analyse de l'article 13.1 de la Loi sur la citoyennet n'tait pas ncessaire et qu'elle avait donc une valeur incidente10. Le juge Mosely a refus de privilgier l'affaire Godinez Ovalle et s'est plutt appuy sur d'autres cas o il a t tabli qu'il n'y avait aucune obligation publique de poursuivre le traitement d'une demande de citoyennet lorsque le ministre dsire enquter sur des questions telles que la cession. La demande de mandamus a t rejete.
# [7] Dans la prsente affaire, nul ne peut affirmer que la demande de citoyennet de l'intim tait [traduction] " complte "  un moment ou  un autre. Le document sur les absences de l'intim, dont toutes les parties s'accordent pour dire qu'il fait partie de la trousse de demande de citoyennet, comporte de graves fausses dclarations concernant les endroits o il s'est trouv dans le monde pendant des mois11. Par exemple, dans ce document, l'intim a dclar, dans la section concernant les pays visits, qu'il avait sjourn en Syrie du XXXX XXXX 2011 au XXXX XXXX 2011, soit pendant 239 jours; l'intim a reconnu  l'audience que cette dclaration tait errone, puisqu'il tait en Iraq pendant la majeure partie de cette priode12. Une demande qui contient de graves fausses dclarations n'est pas " complte ". Cet lment suffit pour distinguer la prsente affaire du raisonnement tenu dans l'arrt Godinez Ovalle.
# [8] Il est peut-tre malheureux que le ministre n'ait pas t en mesure de prsenter la demande de constat de perte de l'asile plus tt, mais j'estime qu'il n'y a eu aucun abus de procdure. Le retard n'est pas draisonnable au point de justifier un sursis tant donn les fausses dclarations et l'article 13.1 de la Loi sur la citoyennet, en vertu duquel de telles suspensions peuvent avoir lieu pour des motifs d'enqute.
# DCISION
# [9] La demande est accueillie pour les motifs exposs ci-aprs.
# FAITS
# [10] L'intim s'est vu accorder l'asile par la SPR en dcembre 2001  l'gard de l'tat de l'Iraq13. Le dossier de la SPR relatif  cette demande d'asile a t dtruit conformment aux politiques de conservation des donnes en vigueur  la Commission de l'immigration et du statut de rfugi du Canada.
# [11]  l'audience, il a t sous-entendu que la demande d'asile de l'intim dcoulait d'une crainte de Saddam Hussein, l'ancien dictateur de l'Iraq, qui a t destitu en 2003 et excut en 2006. Toutefois, aucun tmoignage ni document important n'a t prsent  l'audience  ce sujet. Indpendamment du sort de Saddam Hussein, l'intim a reconnu de lui-mme que la situation en Iraq est trs dangereuse, particulirement pour les personnes qui retournent au pays, qui peuvent tre tues ou enleves  tout moment.
# [12]  partir de 2008, l'intim est retourn de nombreuses fois en Iraq pour de longs sjours, habituellement en passant par des pays tiers. L'intim a obtenu un titre de voyage pour rfugi du Canada, mais il a refus de l'utiliser parce qu'il n'tait pas valide pour les retours en Iraq. L'intim a donc obtenu un nouveau passeport iraquien et il s'en est servi pour voyager.
# [13] Avec le temps, le ministre a fini par apprendre les voyages de l'intim. Aprs un certain temps, il a prsent la demande de constat de perte de l'asile dont il est question ici.
# ANALYSE
# [14] Suivant la LIPR, lorsque le ministre prsente sa demande, la SPR peut rejeter la demande d'asile ou constater la perte de l'asile pour l'une des raisons prvues au paragraphe 108(1) :
# Rejet
# 108(1) Est rejete la demande d'asile et le demandeur n'a pas qualit de rfugi ou de personne  protger dans tel des cas suivants :
# a) il se rclame de nouveau et volontairement de la protection du pays dont il a la nationalit;
# 	b) il recouvre volontairement sa nationalit;
# c) il acquiert une nouvelle nationalit et jouit de la protection du pays de sa nouvelle nationalit;
# d) il retourne volontairement s'tablir dans le pays qu'il a quitt ou hors duquel il est demeur et en raison duquel il a demand l'asile au Canada;
# e) les raisons qui lui ont fait demander l'asile n'existent plus.
# Perte de l'asile
# (2) L'asile vis au paragraphe 95(1) est perdu,  la demande du ministre, sur constat par la Section de protection des rfugis, de tels des faits mentionns au paragraphe (1).
# Effet de la dcision
# (3) Le constat est assimil au rejet de la demande d'asile.
# Exception
# (4) L'alina (1)e) ne s'applique pas si le demandeur prouve qu'il y a des raisons imprieuses, tenant  des perscutions,  la torture ou  des traitements ou peines antrieurs, de refuser de se rclamer de la protection du pays qu'il a quitt ou hors duquel il est demeur.
# [15] Comme je l'explique en dtail ci-dessous, j'estime que le ministre s'est acquitt de son fardeau d'tablir que l'intim s'tait volontairement rclam de nouveau de la protection de l'Iraq au sens de l'alina 108(1)a) et qu'il tait volontairement retourn s'tablir en Iraq au sens de l'alina 108(1)d).
#       L'intim s'est rclam de nouveau de la protection diplomatique de l'Iraq
# [16] Le Guide des procdures et critres  appliquer pour dterminer le statut de rfugi, soit le guide du Haut Commissariat des Nations Unies pour les rfugis (HCR), prvoit ceci au sujet de la cessation :
# Cette clause de cessation s'applique  un rfugi qui possde une nationalit et qui demeure hors du pays dont il a la nationalit. (Le cas du rfugi qui est effectivement retourn " s'tablir " dans le pays dont il a la nationalit est prvu par la quatrime clause de cessation.) Le rfugi qui s'est volontairement rclam  nouveau de la protection du pays dont il a la nationalit n'a plus besoin de la protection internationale. Il a montr qu'il n'tait plus dans la situation de celui qui ne peut ou ne veut se rclamer de la protection du pays dont il a la nationalit.
# [17] L'application de la clause de cessation suppose la ralisation de trois conditions :
# 	a) la volont : le rfugi doit avoir agi volontairement;
#  	b) l'intention : le rfugi doit avoir accompli intentionnellement l'acte par lequel il s'est rclam  nouveau de la protection du pays dont il a la nationalit;
# 	c) le succs de l'action : le rfugi doit avoir effectivement obtenu cette protection.
# [18] Mon analyse relativement  chaque volet du critre est dtaille ci-dessous.
#       Volont
# [19] Dans son tmoignage, l'intim a confirm la preuve du ministre selon laquelle il a obtenu un passeport iraquien de l'ambassade  Ottawa en 2008. Les faits remontent  environ quatre (4) mois aprs que l'intim a obtenu du Canada un titre de voyage pour rfugi. L'intim s'est rendu de lui-mme  l'ambassade et il a montr certains documents qui confirmaient sa citoyennet iraquienne. Un passeport lui a t dlivr. Dans les annes qui ont suivi, il a renouvel son passeport en Iraq.
# [20] Questionn sur la raison pour laquelle il avait besoin d'un passeport iraquien s'il possdait dj un titre de voyage pour rfugi, l'intim a rpondu qu'il ne pouvait voyager en Iraq avec le titre de voyage pour rfugi, donc que le document ne rpondait pas  ses besoins.
# [21] L'intim a prsent de nombreux arguments et lments de preuve au sujet des raisons de ses voyages, mais il vaut mieux les examiner dans le volet du critre portant sur l'" intention ".  ce stade-ci, il suffit de dire que la preuve dmontre clairement que l'intim a volontairement obtenu un passeport iraquien et a voyag en Iraq de son propre chef. Rien ne montre qu'il a t forc de quelque manire que ce soit  agir ainsi ou qu'il l'a fait sous la contrainte. En fait, il semble avoir agi en ayant pleinement conscience des obstacles et des risques.
#       Intention
# [22] Selon le paragraphe 121 du Guide du HCR, il est gnralement prsum qu'une personne a l'intention de se rclamer de nouveau de la protection du pays dont elle a la nationalit lorsqu'elle obtient un passeport national :
# [...] Si un rfugi demande et obtient un passeport national ou le renouvellement de ce passeport, il sera prsum, en l'absence de preuves contraires, avoir voulu se rclamer  nouveau de la protection du pays dont il a la nationalit [...]
# [23] Le paragraphe 122 mentionne que la prsomption est particulirement forte lorsque la personne en cause se sert du passeport national pour retourner dans son pays de nationalit :
# [...] En revanche, l'obtention d'une autorisation de rentrer dans le pays ou d'un passeport national aux fins de retourner dans le pays sera considre, sauf preuve contraire, comme entranant la perte du statut de rfugi [...]
# [24] Dans la prsente affaire, l'intim est retourn en Iraq plus de dix (10) fois, entre 2008 et 2016, au moyen de son passeport de citoyen iraquien nouvellement dlivr; certains de ces sjours ont t trs longs. J'estime que la prsomption selon laquelle l'intim avait l'intention de se rclamer de nouveau de la protection de l'Iraq s'applique.
# [25] Pour rfuter la prsomption concernant l'intention de se rclamer de nouveau de la protection du pays et tablir l'intention contraire, l'intim a expliqu que ses sjours en Iraq avaient des fins altruistes,  savoir prendre soin de sa mre malade, se fiancer, se marier et assister  la naissance de ses enfants, prendre soin de ses enfants malades, faciliter les examens mdicaux aux fins de l'immigration de son pouse et participer  des funrailles. Il soutient galement qu'il souffre lui-mme de nombreux problmes de sant en raison d'un accident de voiture remontant  2002.
# [26] Le rcit de l'intim suivant lequel il devait retourner en Iraq en 2008 pour prendre soin de sa mre, qui tait sur son [traduction] " lit de mort ", pose des problmes de crdibilit. Selon le document sur ses absences, du XXXX XXXX 2008 au XXXX XXXX 2008, l'intim a sjourn pendant 75 jours en Iran pour rendre visite  sa mre14. Ce rcit n'est manifestement pas vridique puisque, mme s'il est possible que l'intim ait transit par l'Iran, il a admis  l'audience qu'il avait  l'poque pass la majeure partie de son temps en Iraq. Une fausse dclaration semblable a t faite relativement  un voyage en [traduction] " Syrie " du XXXX XXXX 2011 au XXXX XXXX 2011, d'une dure de 239 jours. L'intim a admis  l'audience qu'il tait en fait en Iraq pendant cette priode. Les 172 jours passs en " Syrie " du XXXX XXXX 2008 au XXXX XXXX 2009 pour [traduction] " rendre visite  sa fiance " ont en fait t surtout passs en Iraq. J'ai demand  l'intim d'expliquer ses fausses dclarations. Il a dit qu'il avait mentionn les dtails de ses destinations  l'aroport, aux agents d'immigration et  son avocat, qui l'a aid  rdiger sa demande. Il a prsum que les incohrences pourraient avoir t causes par une opration qu'il a subie, mais il avait inform son avocat  l'poque et lui avait prsent tous ses documents. Il ne se rappelle pas s'il en a fait tat ou non par crit.
# [27] L'intim semble rejeter la responsabilit sur son avocat (il n'a pas prcis s'il parlait de son conseil actuel ou d'un autre), mais je refuse d'accorder une valeur probante  cette simple affirmation en l'absence de preuve montrant une conformit avec l'Avis de pratique - Allgations  l'gard d'un ancien conseil, sign le 27 aot 201815. Rien n'indique que ce conseil a reu une dclaration contenant des allgations, un avis crit ou une autorisation signe visant le renoncement  tout privilge, ni qu'il a rpondu. J'estime galement que le reste de l'explication est draisonnable parce que le fait que l'intim a dj abord la question avec des agents d'immigration ou des avocats ne l'absout pas de ses dclarations clairement fausses dans un document sign sous serment. Je soulignerais galement que, dans sa conversation de 2008 avec l'agent, vers la fin de l'interrogatoire, l'intim a modifi son rcit; il avait d'abord affirm qu'il rendait visite  sa mre malade, puis il a dclar qu'il tait [traduction] " acceptable " de prendre des vacances en Iraq tant donn que Saddam avait t destitu16.
# [28] Enfin, il n'y a pas suffisamment de preuve montrant que c'est en raison de problmes mdicaux que l'intim n'tait pas en mesure de relater tous ses sjours en Iraq quand il a sign, en 2014, le document sur ses absences, puisqu'il peut maintenant rapporter certains souvenirs  l'audience. Relativement  la crdibilit de l'intim, je tire une conclusion dfavorable des fausses dclarations contenues dans ses prcdentes dclarations sous serment sur les raisons de ses retours en Iraq.
# [29] Nanmoins, mme si je prsume que la mre de l'intim tait malade, l'intim n'a pas prsent une preuve suffisante pour tablir les dtails de la maladie et l'urgence, pour lui, de retourner en Iraq. La mre serait toujours vivante  la date de l'audience. L'intim a de nombreux frres et surs en Iraq qui ont dj pris soin de leur mre auparavant. Quand ces dtails lui ont t signals, l'intim a rpondu que sa mre ne s'tait pas sentie  l'aise quand elle avait sjourn chez son frre. Elle prfre habiter avec l'intim, qui est trs proche d'elle. Tout en admettant les sentiments subjectifs d'attachement que l'intim prouve  l'gard de sa mre (et le fait qu'elle est plus  l'aise avec lui),  dfaut d'lments de preuve d'ordre mdical dtaills concernant l'tat de sant de sa mre et d'explications venant directement d'elle sur la raison pour laquelle il devait absolument tre prsent en Iraq, j'estime que la preuve n'est pas suffisante pour tablir l'existence de circonstances exceptionnelles telles que la prsomption d'intention serait rfute.
# [30] En outre, les sjours subsquents de l'intim, en 2009, en 2010 et en 2011, n'avaient rien  voir avec l'tat de sant de sa mre. L'intim dsirait plutt rendre visite  sa fiance, puis  son pouse et  ses enfants. L'intim a expliqu que sa mre lui avait demand de se marier avant qu'elle meure, ce qu'il a fait. Ses enfants sont ns peu aprs.  mes yeux, ces faits ne jouent pas en faveur de l'intim. Ces circonstances dmontrent que l'intim a dploy des efforts conscients pour se rclamer de nouveau de la protection de l'Iraq (aprs s'tre vu octroyer l'asile) en commenant une vie parallle en Iraq, avec toutes les obligations qu'elle comportait et au vu et au su de l'tat, par exemple en enregistrant son mariage et la naissance de ses enfants. Il n'a fait aucun effort pour se marier dans un tiers pays plus sr ni pour organiser les visites familiales ou la naissance de ses enfants  l'extrieur de l'Iraq, et ce, mme si, de son propre aveu, il est trs riche et est en mesure de superviser lectroniquement ses entreprises canadiennes  partir de n'importe o dans le monde  condition d'avoir accs  une bonne connexion Internet.
# [31] Je constate que l'intim avait tout  fait l'intention de se rclamer de nouveau de la protection diplomatique de l'Iraq lorsqu'il a demand un passeport iraquien en 2008 et s'en est servi pour aller  de multiples reprises en Iraq. En outre, je juge que l'intim a pris ces dcisions en sachant trs bien que, s'il retournait en Iraq  l'aide d'un passeport iraquien, il risquait de perdre son statut au Canada. L'intim avait l'intention de se faire traiter comme un citoyen iraquien lors de ses multiples voyages, non seulement en Iraq, mais aussi dans les pays voisins, alors qu'il savait qu'il aurait pu se servir d'un titre de voyage pour rfugi du Canada.
#       Succs de l'action
# [32] J'estime que, dans la prsente affaire, l'intim a bel et bien obtenu la protection diplomatique de l'Iraq. Premirement, l'intim a russi  se servir de son passeport iraquien pour voyager un peu partout dans la rgion, dans un certain nombre de tiers pays. Il a bnfici de tous les avantages offerts  un citoyen iraquien (par opposition  ceux dont bnficie un dtenteur de titre de voyage pour rfugi du Canada). Il a t en mesure d'entrer en Iraq et d'en sortir sans problme et son passeport tait examin rgulirement par les reprsentants de l'tat  l'entre et  la sortie.
# [33] Deuximement, l'intim a pass beaucoup de temps en Iraq au fil des ans. Il semble avoir pass la majeure partie de 2012 et de 2011 en Iraq, ainsi que prs de la moiti de 2008 et de 2010. L'intim ne conteste pas l'analyse que fait le ministre de son passeport, lequel rvle des sjours en Iraq aux dates suivantes :
# du XXXX XXXX 2011 au XXXX XXXX 2011 (123 jours);
# du XXXX XXXX 2011 au XXXX XXXX 2011 (47 jours);
# du XXXX XXXX 2012 au XXXX XXXX 2012 (248 jours).
# [34] Les sjours frquents et prolongs dont il est fait tat ci-dessus n'indiquent pas des rapports occasionnels et fortuits avec les autorits du pays,  propos desquels le Guide du HCR fait une distinction.
# [35] Troisimement, l'intim s'est galement dplac entre diffrentes rgions de l'Iraq, soit de la rgion kurde, au nord, relativement sre,  la ville de Bagdad, plus dangereuse. Bien qu'il ait pris certaines mesures pour viter tout danger, notamment en changeant d'appartement chaque nuit qu'il passait  Bagdad, il est raisonnable de penser que ses dplacements en voiture dans diffrentes rgions du pays l'ont probablement expos au risque (et au danger) de rencontrer divers reprsentants de l'tat et les miliciens qui contrlent divers districts. L'intim a log chez diffrents membres de sa famille et il a galement frquent divers hpitaux pour obtenir des soins pour ses enfants, des membres de sa famille et lui-mme,  de multiples occasions. Il ne s'agissait aucunement de visites clandestines, vu leur dure et le nombre de personnes avec qui l'intim a interagi. Je considre que l'intim s'est bel et bien rclam de nouveau de la protection de l'Iraq.
#       Conclusion quant au fait de se rclamer de nouveau de la protection du pays
# [36] Je suis convaincu que le ministre s'est acquitt du fardeau d'tablir que l'intim s'est rclam de nouveau et volontairement de la protection du pays dont il a la nationalit. Cet lment de preuve suffit pour que la demande du ministre soit accueillie.
#
#
# CONCLUSION
# [37] En consquence, la demande du ministre est accueillie, et le constat de perte de l'asile de l'intim est assimil au rejet de sa demande d'asile conformment au paragraphe 108(3) de la LIPR.
#
# (sign)
# Yonatan Rozenszajn
#
#
#
#
#
# 29 juin 2021
#
#
#
#
#
# 1 Pice 1.
# 2 Pices 4 et 5.
# 3 Pice 1, p. 57-58.
# 4 Godinez Ovalle c. Canada (MCI), 2015 CF 935, [2016] 2 RCF 3.
# 5 Ibid., para 65-66.
# 6 GPP c. Canada (MCI), 2018 CF 562, [2018] 4 RCF 538.
# 7 Ibid., para 43.
# 8 Ibid., para 19.
# 9 GPP c. Canada (MCI), 2019 CAF 71.
# 10 Nada c. Canada (MCI), 2019 CF 590, para 23.
# 11 Pice 1, p. 49.
# 12 Ibid.
# 13 Pice 1, p. 12.
# 14 Pice 1, p. 49.
# 15 https://irb.gc.ca/fr/legales-politique/procedures/Pages/allegations-ancien-conseil.aspx
# 16 Pice 1, p. 14.
# ---------------
#
# ------------------------------------------------------------
#
# ---------------
#
# ------------------------------------------------------------
#
#
#
# Immigration and Refugee
# Board of Canada
# Refugee Protection Division
#
# Commission de l'immigration
# et du statut de rfugi du Canada
# Section de la protection des rfugis
#
#
#
#
# SPR.29.01 (1er juin 2021)
# Available in English
#
# 1
#
# Commission de l'immigration
# et du statut de rfugi du Canada
# Section de la protection des rfugis
#
# Immigration and Refugee
# Board of Canada
# Refugee Protection Division
#
#
# SPR.29.01 (1er juin 2021)
# Available in English
#
#
#
#
#
# Dossier de la SPR / RPD File: TC0-11107
#
#
#
#
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# 3263509.txt
#
# RAD File / Dossier de la SAR : TB9-09177
# TB9-09178 / TB9-09179 / TB9-09180
# TB9-09181
#
# Private Proceeding / Huis clos
#
# Reasons and decision ? Motifs et dcision
#
# Persons who are the subject of the appeal
# XXXX XXXX XXXX XXXXXXXX XXXX XXXX XXXXXXXX XXXX XXXX XXXXXXXX XXXX XXXX
# (a.k.a XXXX XXXX XXXX)
# XXXX XXXX XXXX
# Personnes en cause
#
#
#
# Appeal considered / heard at
# Ottawa, ON
# Appel instruit / entendu
#
#
#
# Date of decision
# January 15, 2020
# Date de la dcision
#
#
#
# Panel
# Jillan Sadek
# Tribunal
#
#
#
# Counsel for the persons who are the subject of the appeal
# Bolanle Olusina (Sina) Ogunleye
# Conseil des personnes en cause
#
#
#
# Designated representative
# XXXX XXXX XXXX
# Reprsentant(e) dsign(e)
#
#
#
# Counsel for the Minister
# N/A
# Conseil du ministre
#
#
#
#
#
# REASONS FOR DECISION
# OVERVIEW
# [1] The Principal Appellant (XXXX XXXX XXXX) and her common-law husband, the Associate Appellant (XXXX XXXX XXXX) are citizens of Nigeria. Their children, the minor Appellants (XXXX XXXX XXXX, XXXX XXXX XXXX, XXXX XXXX XXXX) are citizens of the United States. The Associate Appellant is the designated representative of the minor Appellants.
# [2] The Principal Appellant alleges that she may not return to Nigeria because she fears her children will be circumcised and because she fears her uncles will continue to abuse her sexually or even kill her. The Associate Appellant alleges that he may not return to Nigeria as he fears being mistreated by both his own family and the Principal Appellant's family as they do not approve of their union.
# [3] In XXXX 2010, the adult Appellants left Nigeria to come to the United States. The Associate Appellant married an American woman in 2012 and acquired a green card. The Principal Appellant had three children by the Associate Appellant while living in the United States, but did not acquire status in that country, nor did she claim asylum. The adult Appellants and their US born children entered Canada in XXXX 2018 where they claimed asylum.
# [4] The Refugee Protection Division (RPD) determined that the Associate Appellant was excluded from refugee protection on the basis of Article 1E of the Convention Relating to the Status of Refugees due to his status in the United States. The RPD determined that the Principal Appellant's allegations lacked credibility and determined that the children had not established any claim against the United States. All claims were rejected.
# [5] The Appellants contest the exclusion of the Associate Appellant and the RPD's credibility analysis. I have determined that the RPD was correct to reject the claims. The appeals are dismissed.
# ROLE OF THE RAD
# [6] The Refugee Appeal Division (RAD) reviews decisions of the RPD on a standard of correctness after conducting an independent assessment of the evidence before it.1 The exception to this rule is where the RPD enjoys a meaningful advantage in the assessment and weighing of oral testimony heard, which, in particular cases, may attract deference. Unless specifically stated below, I have applied a correctness standard.
# ANALYSIS
# [7] The RPD determined that there was no evidence that the minor Appellants had any claim against the United States, that the Principal Appellant's allegations lacked credibility and her behaviour was indicative of a lack of subjective fear. The RPD also determined that the Associate Appellant was excluded based on Article 1E of the Convention as he had not provided sufficient evidence that he had lost his U.S. permanent residence.
# [8] The Appellants submit that the RPD erred in its exclusion analysis and its analysis of the credibility of the Appellants.
# [9] I have attentively listened to the recording of the RPD hearing, and have carefully reviewed the entire record. I have also taken into account the Chairperson's Guideline 9: Proceedings before the IRB Involving Sexual Orientation and Gender Identity and Expression.2 I agree with the RPD that the Associate Appellant should be excluded, that there is no evidence that the minor Appellants face any risks in returning to the United States and that the Principal Appellant's allegations are not credible. I agree that all claims should be rejected.
# The RPD was correct to exclude the Associate Appellant
# [10] The Appellants assert that the Associate Appellant only had conditional permanent residence in the United States as a spouse of a US citizen; a copy of his green card, valid for only a period of two years, from 2012 to 2014, was presented. The Appellants submit that a conditional permanent resident must file a petition to remove the condition during the 90 days prior to the expiry of the card and that a conditional card cannot be renewed. The Appellants assert that as the Associate Appellant failed to be successful in his petition to remove the condition, he has lost his permanent residence in the U.S.3 The Appellants note that the Minister's intervention materials included proof that the Associate Appellant submitted a petition to US authorities to lift his condition on September 28, 2014, and the status of that application, at the time it was checked in November 2018, was "pending"4. However, the Appellants assert that this renewal application does not mean he did not lose his status.
# [11] The Appellants take issue with the information contained in the Minister's intervention package which included a statement from a Canadian Immigration Officer verifying that the U.S. Immigration and Customs Enforcement's (I.C.E.) database had been checked in July 2018 and indicated the following with regards to the Associate Appellant: "subject is legally residing in the United States as a permanent resident and may live and work in the U.S."5 The Appellants state that there is no indication that the statement relates to the period after the expiration of his Conditional Permanent Resident status. The Appellants also submit: "the document appeared on its face to have been deposed and commissioned by the "declarant" and witnessed by her colleague, instead of being commissioned by a Notary or Commissioner for Oaths."6 The Appellants submit that the document is neither "credible" nor "trustworthy" because the I.C.E.'s statement quoted in the declaration "is vague and lacked context and the declaration was not properly sworn."7
# [12] I disagree with the Appellants that the Immigration Officer's solemn declaration is not a credible or trustworthy source. Without any evidence suggesting the contrary, an Immigration Officer is presumed to be acting impartially within the scope of his or her duties and in an area falling within his or her expertise. As indicated in the Minister's submissions, the issue of the Associate Appellant's permanent residence in the United States was discovered due to a biometric fingerprint match and was not disclosed up front by the Associate Appellant himself. The information obtained from U.S. authorities matches his name, identity and other personal details. There is no reason to believe an error was made when the I.C.E.'s database was checked in July 2018, nor when additional information sharing checks were performed.
# [13] The Appellants also submit that the RPD erred when it indicated that the onus is on the claimant to establish that he had lost his Permanent Resident status in the US, as the Minister failed to present a prima facie case that the Associate Appellant's green card was valid after September 2014.
# [14] With respect, the 1E case law indicates that once there is a prima facie case that the claimant has status in another country, the onus shifts to the claimant to establish that their status has been lost.8 In this case, the Minister's prima facie case was met. There is no additional burden on the Minister to provide evidence that a claimant's permanent resident card was valid on a certain date. I agree with the RPD that the onus was squarely on the Associate Appellant to prove that his status was lost.
# [15] In fact, at the end of the first sitting on December 10, 2018, the RPD put to the Associate Appellant that the information from the Minister indicated he still had status in the U.S., the Associate Appellant replied that he did not know.9 The RPD asked the Associate Appellant if he had any proof that he had lost his status. The Associate Appellant replied that he did not.10 The RPD then asked the Associate Appellant whether he had gone to the U.S. Embassy to check whether he still had status. The Associate Appellant replied that he had not.11 The RPD then decided to suspend the hearing and informed the Associate Appellant to inquire with U.S. authorities as to his status in order to bring greater clarity to the exclusion assessment.
# [16] When the hearing was resumed on March 1, 2018, the Associate Appellant had not gone to inquire about his status with US authorities and no further documentation was provided to the RPD on the issue, other than a photocopy of his expired green card.
# [17] The Minister, on the other hand, did provide further submissions in writing for the second sitting:
# The Minister submits that the evidence provided by the Minister establishes that the Principle Claimant acquired permanent resident status in the United States. As indicated in Wasel, once there is prima facie evidence that the claimant has status in another country, the Minister's burden of proof for exclusion has been met. The onus shifts to the claimant to establish that his status has been lost or that he does not enjoy the rights and benefits by the Federal Court in Shamplou and Shahpari. The Minister suggests that the Claimant should be requested to provide proof of his current immigration status in the United States of America. This information may be accessed from the US Department of State by filing a request pursuant to the Freedom of Information Act (FOJA).
# The Minister submits that since the Principle Claimant's application to remove conditions on his US permanent residence is still pending a decision, his status has not been lost.12
# [18] No reason was provided by the Associate Appellant for his lack of documentation to prove his assertion that he attempted to renew his card and was unsuccessful.13 I agree with the RPD, the Associate Appellant has not established that he no longer has status in the United States, the RPD was therefore correct to exclude him from refugee protection in Canada.
# The RPD did not err in finding the Principal Claimant's allegations lacked credibility
# [19] The Appellants' submissions on their perceived problems with the RPD's credibility analysis are very vague. They submit the following:
# The Appellants aver that the RPD panel erred in its negative credibility findings in paras 35 to 43 of its Decision. The 1st and 2nd Appellants contend that they testified truthfully before the RPD and adduced corroborative documentary evidence in support of our claim to establish our fear of persecution in Nigeria such as: Marriage certificates and Divorce orders; Sworn affidavits from XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Certificates of Death, Medical report from Dr, XXXX XXXX XXXX XXXX XXXX XXXX and the copy of the expired Green Card. The Appellants aver that their testimonies are internally consistent with the documents adduced in support of their claim. The Appellants aver to the RAD that the RPD panel misevaluated the sworn affidavits from XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX Certificates of Death and the Medical report from Dr, XXXX XXXX XXXX XXXX XXXX XXXX adduced in support of their claim. The Appellants submit that the RPD's finding that "the claimant has fabricated her story about being sexually abused by her uncles..." is unsupportable by the evidence as the claimant provided credible testimonies and corroborative documentary evidence to establish their claim. The 2nd Appellant testified truthfully before the RPD that she had no knowledge of the asylum process in USA. It is submitted that the 2nd Appellant has established with credible evidence that she fears persecution in Nigeria. Therefore, the failure to claim in the U.S. is not determinative that she lacks subjective fear in her particular circumstances.14
# [20] I disagree with the Appellants. The RPD's findings are well reasoned.
# [21] I agree with the RPD that the behavior of the Principal Appellant is not compatible with a person who had a subjective fear of returning to Nigeria. She remained in the United States for more than seven years without attempting to obtain legal status in that country or even enquire as to how to make a refugee claim there, yet she alleges that she departed Nigeria in XXXX 2010 with the specific intention of coming to safety and getting away from Nigeria.15 It should be noted that both Appellants are fluent in English, they testified before the RPD without the use of an interpreter and are evidently able to express themselves fully in that language. Furthermore, the Principal Appellant completed the first year of her University studies in linguistics. Yet, she testified that she never attempted to try and find a lawyer or someone who could advise her on how to make a refugee claim in the United States.16 I agree with the RPD that these facts severely damage the credibility of her allegations.
# [22] In terms of her allegations of being sexually abused by her uncles in Nigeria in accordance with "Oro Ile" traditions whereby uncles are entitled to have sex with their brother's orphans, the RPD was correct to point out that the Principal Appellant was unable to present any documentary evidence of such traditional practices. This, despite the fact that the Principal Appellant also testified that these cultural practices were so widely accepted that the police refused to assist her because they were aware of such cultural practices.17
# [23] The RPD was also correct to point out that her evidence of who abused her was inconsistent. In the affidavit she provided from her cousin, it mentions that she was sexually abused by two uncles18 but in her Basis of Claim form and testimony, she stated she was abused by five different uncles.19
# [24] For these reasons, I agree with the RPD that the Principal Appellant's allegations regarding why she fears to return to Nigeria are not credible. The RPD did not err in its credibility analysis.
# CONCLUSION
# [25] No evidence was adduced to establish any serious possibility that the minor Appellants would be persecuted if they returned to the United States, nor that, on a balance of probabilities, they would be personally subjected to a danger of torture, a risk to their lives or a risk of cruel and unusual treatment or punishment should they return to the United States. Consequently, I am satisfied, based on the evidence, that they would not be personally subjected to a risk of torture, a risk to their life or a risk of cruel and unusual treatment or punishment should they return to the United States. I am also not satisfied that they would face a serious possibility of persecution on a Convention ground if they returned to the United States at this time.
# [26] In terms of the Principal Appellant, after my independent review of the evidence in her case, I find the RPD did not err in its finding that her allegations are not credible. I am satisfied, based on the evidence, that she would not be personally subjected to a risk of torture, a risk to her life or a risk of cruel and unusual treatment or punishment should she return to Nigeria. I am also not satisfied that she has demonstrated that there is a serious possibility that she would be persecuted on a Convention ground if she returned to Nigeria at this time.
# [27] Finally, for the aforementioned reasons, I conclude that the RPD was correct to exclude the Associate Appellant from refugee protection on the basis of Article 1E of the Convention Relating to the Status of Refugees due to his status in the United States.
#
#
#
# DETERMINATION
# [28] I dismiss these appeals and confirm the decision of the RPD that the Appellants are neither Convention refugees nor persons in need of protection, pursuant to paragraph 111(1)(a) of the Immigration and Refugee Protection Act.
#
#
# (signed)
# "Jillan Sadek"
#
# Jillan Sadek
#
# January 15, 2020
#
# Date
#
# 1 M.C.I. v. Huruglica, Bujar (F.C.A., no. A-470-14), Gauthier, Webb, Near, March 29, 2016, 2016 FCA 93, at para 103.
# 2 The Chairperson's Guideline 9: Proceedings before the IRB Involving Sexual Orientation and Gender Identity and Expression, May 1, 2017.
# 3 P-2, Appellants' Memorandum, Appellants' record, p.168
# 4 RPD-1, DHS response, RPD record, p. 175
# 5 RPD-1, I.C.E. record, RPD record, p. 158
# 6 P-2, Appellants' Memorandum, Appellants' record, p.170
# 7 P-2, Appellants' Memorandum, Appellants' record, p.170
# 8 Wasell v. Canada (Citizenship and Immigration), 2015 FC 1409 (Can LII).
# Shamlou v. Canada (Minister if Citizenship and Immigration) (1995), 32 Imm. L.R. (2d) 135 (F.C.T.D.) at 152);
# 9 At minute 1h46 of the recording of the first sitting of the hearing on December 10, 2018
# 10 At minute 1h52 of the recording of the first sitting of the hearing on December 10, 2018
# 11 At minute 1h53 of the recording of the first sitting of the hearing on December 10, 2018
# 12 RPD-1, Letter from Canada Border Services Agency Officer, RPD record, p. 240
# 13 At minute 0h07 of the recording of the second sitting of the hearing, March 1, 2019
# 14 P-2, Appellants' Memorandum, Appellants' record, p.173
# 15 At minute 1h20 of the recording of the first sitting of the hearing on December 10, 2018
# 16 At minute 1h22 of the recording of the first sitting of the hearing on December 10, 2018
# 17 At minute 0h39 of the recording of the first sitting of the hearing on December 10, 2018
# 18 RPD-1, Affidavit of XXXX XXXXX, RPD record, p. 206
# 19 At minute 0h27 of the recording of the first sitting of the hearing on December 10, 2018
#
# ---------------
#
# ------------------------------------------------------------
#
#
#
# ---------------
#
# ------------------------------------------------------------
#
# RAD File / Dossier de la SAR : TB9-09177
# TB9-09178 / TB9-09179 / TB9-09180
# TB9-09181
#
#
# RAD.25.02 (April 04, 2019)
# Disponible en franais
# 9
#
#
#
# Immigration and Refugee
# Board of Canada
# Refugee Appeal Division
#
# Commission de l'immigration
# et du statut de rfugi du Canada
# Section d'appel des rfugis
#
#
# RAD.25.02 (April 04, 2019)
# Disponible en franais
#
#
#
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# 2040865.txt
# RPD File No. / N de dossier de la SPR : MB5-02151
# Client ID No. / No ID client : XXXX - XXXX
#
# Huis clos / Private Proceeding
# Reasons and Decision ? Motifs et dcision
# Claimant(s)
# XXXX XXXX XXXX
# Demandeur(e)(s) d'asile
# Date(s) of hearing
# October 14, 2015
# Date(s) de l'audience
# Place of hearing
# Montreal, Quebec
# Lieu de l'audience
# Date of decision
# and reasons
# October 22, 2015
# Date de la dcision
# et des motifs
# Panel
# Linda Parker
# Tribunal
# Counsel for the claimant(s)
# Me Luciano Mascaro
# Conseil(s) du (de la/des)
# demandeur(e)(s) d'asile
# Designated representative
# N/A
# Reprsentant(e) dsign(e)
# Counsel for the Minister
# Annie Pham
# (Deposit of documents)
# Conseil du (de la) ministre
#
#
# REASONS FOR DECISION
#
# INTRODUCTION
# [1] The claimant, XXXX XXXX XXXX, is a citizen of Colombia and is claiming refugee protection under sections 96 and 97 of the Immigration and Refugee Protection Act (the Act).
# DETERMINATION
# [2] The tribunal finds that the claimant has not satisfied the burden of establishing that there is a serious possibility of persecution on a Convention ground, or that, on a balance of probabilities, the claimant would personally be subjected to a danger of torture or face a risk to life or a risk of cruel and unusual treatment or punishment upon return to his country.
# ALLEGATIONS
# [3] The claimant has alleged in his Basis of Claim Form1 (BOC) that he was a driver for a businessman who had XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Colombia. He would deliver XXXX XXXX and XXXX XXXX XXXX XXXX such as XXXX, the XXXX, and a XXXX XXXX XXXX XXXX XXXX XXXX. These men were allegedly convicted and imprisoned for having links with paramilitary groups that were involved in drug trafficking, kidnapping, and murder. The XXXX XXXX XXXX XXXX XXXX, XXXX XXXX, received a conditional release and his whereabouts are unknown. He was sentenced to 20 years of prison and is wanted by the Colombian authorities.
# [4] The claimant alleges that it is because of his activities with these individuals that he is wanted by the guerrillas, because he knows a lot of things. The paramilitaries also want to kill him so that he does not disclose information that may implicate other people.
# [5] The claimant arrived in Canada with a multiple entry visitor/business visa2 on XXXX XXXX, 2011, and claimed asylum in Montreal sometime in May 20153.
# MINISTER'S REQUEST FOR A POSTPONEMENT
# [6] On July 16, 2015, the Minister of Public Safety requested a postponement and submitted exhibits4 in order to obtain court documents from the United States regarding the claimant's criminal history in this country. According to National Crime Information Center (NCIC) results, the claimant would have been in the United States from approximately 1984 to 1994. On September 14, 2015, the Canada Border Services Agency (CBSA) sent a letter5 indicating that following the reception of court documents, the claimant was found eligible and that the Minister would not be intervening. The tribunal, after analysing the claimant's criminal history and the documents filed, did not pursue the issue of a 1F(b) exclusion.
# ANALYSIS
# Identity
# [7] The identity of the claimant as a national of Colombia is established by his testimony and the supporting documentation filed, namely his passport6.
# Credibility
# [8] After reviewing all of the evidence, the panel is of the opinion that the refugee protection claimant is not a credible or trustworthy witness with respect to his allegations that he would be persecuted in Colombia should he return. The tribunal noted a number of credibility problems in the claimant's testimony and noted a delay of almost four years before claiming asylum in Canada. The claimant's testimony lacked detail, and there were contradictions, inconsistencies, and important omissions.
# [9] With regards to the agents of persecution, the claimant's testimony was very vague; he provided general information and he simply referred to his persecutors throughout his testimony as the guerrillas and the paramilitaries, with little detail. The claimant has alleged that the root cause of his problems is related to his employment with a businessman, who had links with public servants, who had links with paramilitaries. The tribunal noted that the claimant submitted no documentation to support the duration of his employment with this employer, other than a police report from 2002 filed by a Mr. XXXX, who was his employer at that time, regarding a robbery. Further, the tribunal found that the claimant's testimony was unclear and convoluted regarding his employment; at first, he indicated that he worked for governors and XXXX, and he then said that he worked for a businessman/engineer.
# [10] The tribunal further noted contradictions between the claimant's testimony and his immigration documents regarding the date of his alleged employment with this businessman. At the hearing, he testified that he worked for his employer from 2000 until 2010. The claimant's BOC narrative indicated that he worked for the businessman from 1998 until 2003. A week before the hearing, the claimant filed a correction to his BOC narrative whereby he erased those dates; however, in his corrected narrative, he did not replace those dates with any other dates and the duration of his employment was simply omitted.
# [11] When asked for an explanation for the correction, the claimant declared that he did not know why those dates were there and that he did not write them in. The claimant was then confronted with the dates in form IMM 5669, at question 87, whereby the claimant declared that he worked from 2001 until his departure from Colombia in XXXX 2011 for a company called XXXX XXXX. The clamant responded that he did not know why those dates were there, that he must have made a mistake, and that that was the name of his employer's company.
# ...
#
# [21] Le ministre a aussi prsent un courriel en date du 29 aot 2012, envoy par un spcialiste en matire d'inscription des Indiens, expliquant le processus d'inscription en vertu de la Loi sur les Indiens et l'exigence de soumettre le certificat de naissance dtaill original mis par le bureau de l'tat civil8. Il a prsent un exemplaire de la demande d'inscription pour obtenir le statut d'Indien inscrit9.
#
# [22] Le ministre n'a pas prsent d'autres lments de preuve lorsque l'audience a repris le 7 septembre  9 heures.
#
# [23] Lors de cette audience, le ministre a eu l'occasion de ragir  la prsentation en preuve  du certificat de naissance de la grand-mre maternelle de M. Norton, mis par la province de Qubec10.
#
# [24] Le tribunal a soulign que ce document renvoie  un endroit appel Saint-Rgis dans la province du Qubec.
#
# [25] Le ministre a soutenu que les lments de preuve ne permettaient pas d'tablir si la mre de M. Norton est ne dans la rserve de Saint-Rgis  Akwesasne sur le ct canadien, ou dans l'tat de New York aux tats-Unis.
#
# [26] Durant l'aprs-midi du 7 septembre, le ministre a demand que l'audience soit ajourne afin d'tre en mesure d'obtenir le certificat de naissance dtaill de la mre de M. Norton (indiquant son lieu de naissance), et afin de la convoquer comme tmoin pour confirmer o elle est ne. Il s'attendait  ce qu'elle soit prsente  l'audience, mais elle n'y tait pas. Il a ajout qu'un agent de l'ASFC avait communiqu avec un agent des Affaires indiennes ce matin-l et qu'il a t inform que le certificat de naissance dtaill de Mme Ransom ne serait pas prsent sans le consentement de celle-ci, conformment  la Loi sur la protection des renseignements personnels. Il a soutenu qu'il ne serait pas convaincu que la mre de M. Norton est une citoyenne canadienne  moins qu'elle ne prsente son certificat de naissance dtaill.
#
# [27] Le conseil de M. Norton s'est oppos  la demande d'ajournement. Il a fait valoir que le ministre s'tait vu accorder suffisamment de temps pour prsenter ses lments de preuve. Il a dclar que M. Norton avait prsent assez d'lments de preuve pour dmontrer que lui et sa mre avaient qualit de citoyen canadien et que sa grand-mre tait une Canadienne. Il a rappel au tribunal que M. Norton avait pass 59 jours en dtention. Il a ajout que le ministre n'avait pas inscrit Mme Ransom sur la liste des tmoins.
#
# [28] Le tribunal a refus d'ajourner l'audience pour les motifs suivants :
#
# -  l'audience du 17 aot, M. Norton a prsent le certificat de baptme de sa mre, Mme Ransom, dlivr par l'glise de Saint-Rgis au Qubec;
# - il tait prvu que l'audience du 7 septembre s'amorcerait  9 heures et se poursuivrait toute la journe;
# - le 22 aot, le tribunal a envoy une lettre aux deux parties concernant le certificat de baptme, les invitant  prsenter des observations ainsi que tout lment de preuve ayant trait aux consquences de la naissance de la mre de M. Norton dans la rserve de Saint-Rgis sur le statut de M. Norton aux termes de la Loi sur la citoyennet ou de la Loi sur les Indiens;
# - le 29 aot, le ministre a transmis par tlcopieur des observations crites ainsi que deux documents11; il a soutenu qu'il n'existe aucune rserve au Canada qui s'appelle Saint-Rgis et que la mre de M. Norton n'est pas ne au Canada;
#  - le ministre n'a pas convoqu la mre de M. Norton  venir tmoigner lors de l'audience prvue le 7 septembre12;
# - le ministre n'a pas tent d'obtenir, avant l'audience du 7 septembre, le certificat de naissance dtaill de la mre de M. Norton;
# - lors de la reprise de l'audience le 7 septembre  9 heures, le ministre tait prt  procder et il n'a prsent aucun autre lment de preuve;
#        - en de telles circonstances, la demande d'ajournement tait inopportune;
# - le certificat de naissance dtaill de la mre de M. Norton ne sera pas prsent sans le consentement de celle-ci, conformment  la Loi sur la protection des renseignements personnels;
# - l'ajournement retarderait l'enqute de manire draisonnable et causerait vraisemblablement un prjudice  M. Norton puisqu'il est demeur en dtention pendant toute la dure de la prsente instance; il est dtenu depuis le 10 juillet, et l'ajournement prolongerait la dure de la dtention;
# - le tribunal n'a pas comptence pour dtenir M. Norton s'il est un citoyen canadien; la question concernant son statut au Canada doit donc tre rgle rapidement;
# - le tribunal doit poursuivre avec clrit, dans la mesure o les circonstances et les considrations de justice naturelle le permettent13.
#
#          		2. La position de M. Norton
#
# [29] Le conseil de M. Norton a soutenu que le nom " James Sheldon Norton " est une fiction juridique. Il le dsigne sous le nom de James-Sheldon, demandeur de droit14.
#
# [30] D'aprs les dossiers des Indiens de Saint-Rgis certifis le 15 aot 2012, son nom autochtone est Tekowrente et sa manifestation (ou naissance) est survenue le 13 avril 197115. Son lieu de naissance est ga.yo.go.ho:no'ga.noh.sa'. Son nom tranger est James-Sheldon, parent de Norton. Le demandeur, ou le prsum dfendeur, est de descendance autochtone; il est Onkwehonwe, appartenant  l'Assemble des Indiens de Saint-Rgis, et n'est natif ni des tats-Unis ni du Canada. Il soutient qu'il habite au village de Saint-Rgis, Kanienke, qui ne se trouve ni au Canada, ni aux tats-Unis.
#
# [31] Le conseil de M. Norton a soutenu qu'il n'y a aucun lment de preuve attestant que le demandeur est n  Rochester (New York). Le document de mise en dtention dpos en preuve par le ministre16 n'est pas un document crdible.
#
# [32] Le conseil a soutenu que le lieu de naissance de M. Norton est ga.yo.go.ho:no'ga.noh.sa', qui ne fait partie ni des tats-Unis, ni du Canada.
#
# [33] Pri d'indiquer son lieu de naissance  l'audience du 7 septembre, M. Norton a refus de rpondre.
#
# [34] Le conseil de M. Norton a soutenu que la mre de ce dernier est Kanienkehaka, et n'est native ni des tats-Unis, ni du Canada. Selon les dossiers des Indiens de Saint-Rgis, son nom autochtone est Kentiokwenhawi. Sa manifestation (ou naissance) est survenue le 12 juillet 194517. Elle est ne au village de Saint-Rgis, Kanienke. Son nom tranger est Patricia-Ann, parente de Ransom.
#
# [35] Selon les dossiers des Indiens de Saint-Rgis, sa grand-mre maternelle est Tekawennake. Elle est ne le 18 janvier 192018,  Christie Island, Akwesasne, Kanienke. Son nom tranger est Margaret, parente de Lazore.
#
# [36] Dans son argumentation  l'audience du 7 septembre, le conseil de M. Norton a avanc que ce dernier avait droit  la citoyennet canadienne tant donn que les lments de preuve indiquent que sa mre et sa grand-mre ont la citoyennet canadienne. Il s'est fond sur les deux documents qu'il a dposs. Le premier est le certificat de baptme de sa mre, Patricia Ann Ransom, indiquant que cette dernire est ne le 22 juillet 1945 dans la Rserve de Saint-Rgis; elle est la fille d'Alexander Ransom et de Margaret Lazore. Le deuxime est le certificat de naissance du Qubec de sa grand-mre maternelle, Marguerite Lazore, qui indique que cette dernire est ne le 18 janvier 1920  Saint-Rgis, qui se trouve au Qubec.
#
#       3. Les conclusions du tribunal
#
# [37] Il convient de noter que le tribunal ne disposait pas d'un certificat de naissance pour dterminer avec certitude le nom et le lieu de naissance de l'intress, car aucun document de ce genre n'a t dpos en preuve.
#
# [38] Le tribunal note galement que la date de naissance prsume, soit le 13 avril 1971, n'est pas conteste.
#
# [39] Un permis de conduire de l'tat de New York a t dlivr en 2011  James Sheldon Norton, n le 13 avril 197119. Une carte de membre de la tribu mohawk de Saint-Rgis a t dlivre  M. James Sheldon Norton20. Une attestation de la tribu mohawk de Saint-Rgis a t dlivre le 15 aot 2012  M. James Sheldon Norton21.
#
# [40] Le tribunal conclut que le nom autochtone de l'intress est Tekowrente. Bien que cette personne estime que le nom " James Sheldon Norton " est un nom tranger, il s'agit du nom qui figure sur son permis de conduire de l'tat de New York, sa carte de membre de la tribu mohawk de Saint-Rgis et son attestation de la tribu mohawk de Saint-Rgis. Par consquent, avec tout le respect que le tribunal doit  Tekowrente, le tribunal le dsignera sous le nom de James Sheldon Norton aux fins de la prsente dcision.
#
# [41] Bien que le tribunal conclue que M. Norton est n le 13 avril 1971, il ne semble pas y avoir de preuve crdible ou digne de foi attestant de son lieu de naissance. Il est bien malheureux que M. Norton ait choisi de demeurer muet sur cette question durant son tmoignage. Ce silence non expliqu a donn l'impression ngative que M. Norton ne souhaitait pas collaborer.
#
# [42] Le seul lment de preuve se rapportant au lieu de naissance de M. Norton  la disposition du tribunal est le document de mise en dtention dpos par le ministre22. Le tribunal ne peut accorder beaucoup de poids  ce document, malgr sa pertinence, car la source et la date du document sont inconnues.
#
# [43] De toute manire, rien ne permet de conclure que M. Norton est n au Canada. De plus, le ministre et M. Norton n'ont pas soutenu qu'il est n au Canada.
#
# [44] Par consquent, le tribunal conclut que M. Norton est n  l'extrieur du Canada.
#
# [45] La rponse du ministre de la Citoyennet et de l'Immigration du Canada, attestant n'avoir trouv aucun document indiquant que M. Norton ait obtenu un certificat de citoyennet canadienne ou de naturalisation, constitue une prsomption trs forte que M. Norton n'a pas la citoyennet canadienne, mais elle ne tranche pas dfinitivement la question23. Le tribunal doit rendre une dcision  la lumire de la preuve qui lui est prsente.
#
# [46] Le ministre ne conteste pas le fait que Mme Patricia Ann Ransom, ne le 10 juillet 1945, est la mre de M. Norton.
#
# [47] Le ministre n'a prsent aucun lment de preuve qui permette de conclure que Mme Ransom est ne  l'extrieur du Canada.
#
# [48] M. Norton a prsent des lments de preuve crdibles et dignes de foi attestant la naissance de sa mre au Canada. Le certificat de baptme original de Mme Patricia Ann Ransom a t prsent en preuve24. Il n'y a pas la moindre raison de mettre en doute la validit de ce document. Le certificat de baptme est un document officiel qui tablit son contenu. Il s'agit d'un document crdible et digne de foi dlivr le 20 janvier 1993 par le pasteur de l'glise de Saint-Rgis, au Qubec, dans la rserve de Saint-Rgis.
#
# [49] Le certificat de baptme atteste que Mme Patricia Ann Ransom est ne dans la rserve de Saint-Rgis. Elle est la fille de M. Alexander Ransom et de Mme Margaret Lazore.
#
# [50] Aucun lment de preuve ne corrobore l'argument soulev par le conseil du ministre,  savoir qu'il n'y a pas de rserve de Saint-Rgis au Canada. La dclaration ci-dessous dans les observations du conseil du ministre ne peut tre considre comme tant un lment de preuve :
#
#
# [Traduction]
# J'ai communiqu avec le ministre des Affaires autochtones et Dveloppement du Nord Canada et demand s'il y avait une rserve au Canada qui portait le nom de Saint-Rgis. On m'a avis qu'il n'y a AUCUNE rserve au Canada portant le nom de Saint-Rgis.
#
#
# [51] De plus, cette information n'est pas suffisamment prcise pour tre fiable. Par exemple, elle ne permet pas de savoir s'il y avait une rserve de Saint-Rgis au Canada en 1945, au moment de la naissance de la mre de M. Norton. Elle ne permet pas de savoir s'il pourrait y avoir une rserve de Saint-Regis aux tats-Unis.
#
# [52] M. Norton a dpos en preuve le certificat de naissance de sa grand-mre maternelle, Mme Marguerite Lazore. Ce document a t dlivr par le directeur de l'tat civil du Qubec le 19 dcembre 2003. Il atteste qu'elle est ne le 18 janvier 1920  Saint-Rgis25.
#
# [53] Ce document officiel dlivr par le directeur de l'tat civil du Qubec dmontre qu'il existe un endroit du nom de Saint-Rgis dans la province du Qubec.
#
# [54] En l'absence de toute preuve, le tribunal conclut que M. Norton a dmontr selon la prpondrance des probabilits que sa mre est ne au Canada. Il semble qu'elle soit ne dans la rserve de Saint-Rgis le 10 juillet 1945 et baptise  l'glise de Saint-Rgis, au Qubec, le 22 juillet 1945.
#
# 	4. La Loi sur la citoyennet
#
# [55] Bien que M. Norton soit n  l'extrieur du Canada en 1971, il a droit  la citoyennet canadienne si sa mre avait qualit de citoyenne au moment de la naissance26.
#
# [56] L'alina 3(1)g) de la Loi sur la citoyennet est ainsi libell :
#
# 3(1) Sous rserve des autres dispositions de la prsente loi, a qualit de citoyen toute personne :
# 	[...]
# g) qui, ne  l'tranger avant le 15 fvrier 1977 d'un pre ou d'une mre ayant qualit de citoyen au moment de la naissance, n'est pas devenue citoyen avant l'entre en vigueur du prsent alina; [...]
#
# [57] Aux termes de l'alina 3(7)e), M. Norton est rput tre citoyen  partir du moment de sa naissance :
#
# (7) Malgr les autres dispositions de la prsente loi et l'ensemble des lois concernant la naturalisation ou la citoyennet en vigueur au Canada avant l'entre en vigueur du prsent paragraphe :
# [...]
# e) la personne vise aux alinas (1)g) ou h) est rpute tre citoyen  partir du moment de sa naissance; [...].
#
# [58] La question  trancher est celle de savoir si la mre de M. Norton avait qualit de citoyenne au moment de sa naissance en 1945.
#
# [59] Il est tabli que la mre de M. Norton est ne au Qubec le 10 juillet 1945. Elle tait initialement considre comme tant un sujet britannique, puis est devenue une citoyenne canadienne de naissance  la suite de l'entre en vigueur de la Loi sur la citoyennet27.
#
# [60] Rien ne permet de conclure qu'elle a perdu sa citoyennet canadienne aprs sa naissance.
#
# [61] Il n'y a rien dans la preuve et les observations qui mette en doute qu'elle est une citoyenne canadienne de naissance du fait qu'elle est ne dans la rserve de Saint-Rgis.
#
# [62] Dans ces circonstances particulires, le tribunal conclut que la mre de M. Norton tait une citoyenne canadienne au moment de sa naissance.
#
# [63] Par consquent, le tribunal conclut que M. Norton a droit  la citoyennet canadienne aux termes de l'alina 3(1)g) de la Loi sur la citoyennet.
#
# CONCLUSION
#
# [64] De l'avis du tribunal, le ministre n'a pas dmontr qu'il a des motifs raisonnables de croire que M. Norton n'est pas un citoyen canadien.
#
# [65] Le tribunal rend une dcision favorable et aucune mesure d'expulsion n'est prise.
#
#
#
#
#
#
#
# Original sign par
#
#
# Me Marie-Louise Ct, commissaire
#
#
#
# c.c.	M. Michel Gallant, conseil du ministre
# 	Noble Gi-Ni-Ti-Harcum-El: Bey, conseil de l'intress
#
#
# Traduction de la CISR
# Langue originale : anglais
# 1 Pice C-4.
# 2 Marshall c. Canada (Ministre de la Citoyennet et de l'Immigration), 2004 CF 34.
# 3 Pice C-4.
# 4 Pice C-19.
# 5 Pice C-5.
# 6 Pice D-1(E).
# 7 Pice C-18(1).
# 8 Pice C-18(2).
# 9 Pice C-18(3).
# 10 Pice D-6.
# 11 Pices C-18(1)  C-18(3).
# 12 Paragraphe 32(1) des Rgles de la Section de l'immigration.
# 13 Paragraphe 162(2) de la Loi.
# 14 Pice D-1, en liasse.
# 15 Pice D-1 (C).
# 16 Pice C-19 .
# 17 Pice D-1 (C).
# 18 Pice D-1 (C).
# 19 Pice C-8.
# 20 Pice C-8.
# 21 Pice D-1(B).
# 22 Pice C-19.
# 23 Marshall c. Canada (Ministre de la Citoyennet et de l'Immigration), 2004 CF 34.
#
# 24 Pice D-1(E).
# 25 Selon les dossiers des Indiens de Saint-Rgis, elle s'appelle Tekawennake. Sa manifestation (ou naissance) est survenue le 18 janvier 1920 (pice D-1 (C)). Le lieu de la naissance est Christie Island, Akwesasne, Kanienke. Son nom tranger est Margaret, parente de Lazore.
# 26 Jabour c. Canada (Citoyennet et Immigration), 2012 CF 98.
# 27 LC 1946, chap. 15.
# ---------------
#
# ------------------------------------------------------------
#
# ---------------
#
# ------------------------------------------------------------
#
#
#
# 14
#
#
# No de dossier de la SI / ID File No.: 0018-B2-00756
# 		Date : 14 septembre 2012
#
#
#
#
#
#
#
#
#
#
#
#
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %% [markdown]
# ### Excellent!
#
# On 500 included files 98.4% accuracy on decision date, with the 8 inaccuracies sometimes involving
# confusing decision date and hearing date, and in those cases the dates were mostly very
# close together.
#
# On 500 included files, 99.8% correct inclusion, with the one error being a weird edge case
# that arguably isn't even an error (it was decided by RPD, but it was not a refugee claim
# but instead an issue about unauthorized counsel).
#
# On 500 raw files 100% accuracy in terms of all those included being correctly included.
#
# On 500 raw files, 99% accuracy in terms of properly including those that should be included. The
# five missed RPD cases mostly involved typos in the RPD number or in the date, or unusual ways of recording the date.
#
# Overall, this is good enough. I manually removed the case that was not a refugee claim. We could work
# further on the dates, which would improve both the decision date accuracy and the handful of
# missing RPD cases, but we're in diminishing returns.
